# %%
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
iris = load_iris()
x = pd.DataFrame(iris.data, columns=iris.feature_names)
y = pd.DataFrame(iris.target, columns=["target"])

# %%
model = KMeans(n_clusters=3, random_state=41)
model.fit(x)
# Out:
# KMeans(n_clusters=3, random_state=41)

# %%
plt.figure(figsize=(14, 14))
colormap = np.array(["red", "lime", "black"])
plt.subplot(2, 2, 1)
plt.scatter(x["petal length (cm)"], x["petal width (cm)"], c=colormap[y.target], s=40)
plt.xlabel("petal length (cm)")
plt.ylabel("petal width (cm)")
plt.title("Actual")
plt.subplot(2, 2, 2)
plt.scatter(
    x["petal length (cm)"], x["petal width (cm)"], c=colormap[model.labels_], s=40
)
plt.xlabel("petal length (cm)")
plt.ylabel("petal width (cm)")
plt.title("K-Means")
# Out:
# Text(0.5, 1.0, 'K-Means')

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']
